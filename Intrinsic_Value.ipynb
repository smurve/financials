# %%
# %load_ext autoreload
# %autoreload 2

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import seaborn as sns
import pandas as pd
import json
from urllib.request import Request, urlopen
import numpy as np

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
sns.set_style('darkgrid')
sns.set(rc={'figure.figsize': (12,4)})

# %%
from webapis.guru import Guru
from webapis.yahoo import etf_components

# %%
guru = Guru('73142da8657cc5dfa541b546d1560131:4886c27790bc76bd5e076340a403ade5')

# %% [markdown]
# ---
# ## Total Equity over time

# %%
financials=guru.financials('TSM')

# %%
bs = guru.balance_sheet(financials)
bs['Total Equity'].plot();
bs[['Total Assets', 'Total Liabilities', 'Total Equity']]['2004':].head()
# Out:
#             Total Assets  Total Liabilities  Total Equity
# Date
# 2004-03-28  12640.652348        2234.433722  10406.218626
# 2004-06-28  13124.703539        2648.446691  10476.256848
# 2004-09-28  13622.985345        2451.946337  11171.039008
# 2004-12-28  15550.167359        3126.191549  12423.975810
# 2005-03-28  15477.350501        2103.267107  13374.083394

# %% [markdown]
# ---
# ## Growth Multiple

# %%
Guru.growth_multiple(8)
# Out:
# 10.939772419859002

# %% [markdown]
# ---
# ## 6 years FCF average

# %%
cfs = guru.cashflow_statement(financials)
cfs['2005-03':].plot(y=['FCF 6y avg']);

# %% [markdown]
# ---
# ## Putting it all together

# %%
p_fv = guru.adjusted_fair_value('TSM', 1.8)
p_fv['2007':].plot();

# %%
p_fv = guru.adjusted_fair_value('NVDA', 1.8)
p_fv['2007':].plot();

# %%
p_fv = guru.adjusted_fair_value('SWKS', 1.8)
p_fv['2007':].plot();

# %%
p_fv = guru.adjusted_fair_value('TOELY', 1.8)
p_fv['2007':].plot();
